# %% [markdown]
# <h3> Listing data files </h3>
# Using sample dataset

# %%
# %fs ls /databricks-datasets/structured-streaming/events/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# <h3> Data Preview</h3>
# This is how the data looks in all of the files

# %%
# %fs head /databricks-datasets/structured-streaming/events/file-2.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Truncated to first 65536 bytes]
# {&quot;time&quot;:1469510364,&quot;action&quot;:&quot;Close&quot;}
# {&quot;time&quot;:1469510365,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469510366,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469510368,&quot;action&quot;:&quot;Close&quot;}
# {&quot;time&quot;:1469510370,&quot;action&quot;:&quot;Close&quot;}
# {&quot;time&quot;:1469510371,&quot;action&quot;:&quot;Open&quot;}
# {&quot;time&quot;:1469510372,&quot;action&quot;:&quot;Close&quot;}
# {&quot;time&quot;:1469510380,&quot;action&quot;:&quot;Close&quot;}
# ...

# %% [markdown]
# <h3> Defining Schema</h3>
# The data format is already known, so we can define the schema to speed up processing using StructType

# %%
from pyspark.sql.types import *

#Reference to the path where input data is stored
inputPath = "/databricks-datasets/structured-streaming/events/"

jsonSchema = StructType([ StructField("time", TimestampType(), True), StructField("action", StringType(), True) ])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# <h3> Reading the data in batch/static mode </h3>

# %%
# Static DataFrame representing data in the JSON files
staticInputDF = (
  spark
    .read
    .schema(jsonSchema)
    .json(inputPath)
)

display(staticInputDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# We can compute the number of "open" and "close" actions with one hour windows. To do this, we will group by the action column and 1 hour windows over the time column.

# %%
from pyspark.sql.functions import *      # for window() function

staticCountsDF = (
  staticInputDF
    .groupBy(
       staticInputDF.action, 
       window(staticInputDF.time, "1 hour"))    
    .count()
)
staticCountsDF.cache()

# Register the DataFrame as table 'static_counts'
staticCountsDF.createOrReplaceTempView("static_counts")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Running SQL Query upon the table

# %%
# %sql select action, sum(count) as total_count from static_counts group by action
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>total_count</th></tr></thead><tbody><tr><td>Close</td><td>50000</td></tr><tr><td>Open</td><td>50000</td></tr></tbody></table></div>

# %%
# %sql select action, date_format(window.end, "MMM-dd HH:mm") as time, count from static_counts order by time, action
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
